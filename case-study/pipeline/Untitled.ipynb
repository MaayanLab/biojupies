# %%
# %cd /Users/denis/Documents/Projects/jupyter-notebook/notebook-generator/case-study
# Out:
# /Users/denis/Documents/Projects/jupyter-notebook/notebook-generator/case-study

# %%
import pandas as pd

# %%
infile = 'rawdata/p53_MDM2_p21_RNA.xlsx'

# %%
signature_dataframe = pd.read_excel(infile, index_col='biojupies')

# %%
signature_dataframe.head()
# Out:
#           cell_line             cell_type  \
# biojupies
# 2qkZ16seR        BJ            fibroblast
# eDzO7T5rI       MA9  cord blood stem cell
# AdaIRUcPL   HCT-116     colorectal cancer
# oGwULp9lH   HCT-116     colorectal cancer
# 40Lyd8Z1G   HCT-116     colorectal cancer
#
#                                                     ctrl_ids organism  \
# biojupies
# 2qkZ16seR                   GSM2837350 GSM2837351 GSM2837352    human
# eDzO7T5rI  GSM2436724 GSM2436725 GSM2436726 GSM2436727 GS...    human
# AdaIRUcPL        GSM2652424 GSM2652425 GSM2652420 GSM2652421    human
# oGwULp9lH  GSM2664062 GSM2664064 GSM2664066 GSM2664068 GS...    human
# 40Lyd8Z1G        GSM2474241 GSM2474242 GSM2474245 GSM2474246    human
#
#                                                     pert_ids  \
# biojupies
# 2qkZ16seR  GSM2837353 GSM2837354 GSM2837355 GSM2837356 GS...
# eDzO7T5rI  GSM2436729 GSM2436730 GSM2436731 GSM2436732 GS...
# AdaIRUcPL        GSM2652418 GSM2652419 GSM2652422 GSM2652423
# ...

# %%
clustered_heatmap = sns.clustermap(correlation_dataframe, cmap="RdBu_r");

# %%
# %%R
# library("RColorBrewer")

# %%
# %load_ext rpy2.ipython

# %%
# %%R -i correlation_dataframe -h 700 -w 700
# pheatmap(correlation_dataframe,
#          color = colorRampPalette(rev(brewer.pal(n = 7, name ="RdBu")))(100),
#          show_rownames=FALSE, show_colnames=FALSE, border_color=NA)
